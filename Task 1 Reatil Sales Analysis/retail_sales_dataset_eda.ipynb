# %%
import pandas as pd

# %%
df = pd.read_csv("retail_sales_dataset.csv")

# %% [markdown]
# TOp 5 Customers

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  24-11-2023     CUST001    Male   34           Beauty
# 1               2  27-02-2023     CUST002  Female   26         Clothing
# 2               3  13-01-2023     CUST003    Male   50      Electronics
# 3               4  21-05-2023     CUST004    Male   37         Clothing
# 4               5  06-05-2023     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %% [markdown]
# Info of CSV

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   str
#  2   Customer ID       1000 non-null   str
#  3   Gender            1000 non-null   str
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   str
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), str(4)
# memory usage: 70.4 KB

# %% [markdown]
# CSV Describes

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %% [markdown]
# Shape

# %%
df.shape
# Out:
# (1000, 9)

# %% [markdown]
# Columns

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='str')

# %% [markdown]
# NUll values

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %% [markdown]
# Total Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Total Sum

# %%
df["Total Amount"].sum()
# Out:
# np.int64(456000)

# %% [markdown]
# Mean of Total amount

# %%
df["Total Amount"].mean()
# Out:
# np.float64(456.0)

# %% [markdown]
# Product Category

# %%
df["Product Category"].value_counts()
# Out:
# Product Category
# Clothing       351
# Electronics    342
# Beauty         307
# Name: count, dtype: int64

# %% [markdown]
# Gender

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Female    510
# Male      490
# Name: count, dtype: int64

# %% [markdown]
# Top Selling Product

# %%
import pandas as pd
df=pd.read_csv("retail_sales_dataset.csv")
df.groupby("Product Category")["Quantity"].sum().sort_values(ascending=False)
# Out:
# Product Category
# Clothing       894
# Electronics    849
# Beauty         771
# Name: Quantity, dtype: int64

# %% [markdown]
# Most Profitable Category

# %%
df.groupby("Product Category")["Total Amount"].sum().sort_values(ascending=False)
# Out:
# Product Category
# Electronics    156905
# Clothing       155580
# Beauty         143515
# Name: Total Amount, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df["Date"] = pd.to_datetime(df["Date"], dayfirst=True)
df["Month"] = df["Date"].dt.month_name()

monthly_sales = df.groupby("Month")["Total Amount"].sum()

monthly_sales.plot(kind="bar", figsize=(10,5))
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()

# %%
df["Product Category"].value_counts().plot(kind="bar",figsize=(8,5))
plt.title("Product Category Distribution")
plt.xlabel("Product Category")
plt.ylabel("count")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # The clothing category has the highest number of transactions , followed closely by electronics. Beauty products have the lowest categories .The suggests that customers purchase Clothing products more frequently than other categories.

# %% [markdown]
# ## Gender Distribution

# %%
df["Gender"].value_counts().plot(kind="pie",autopct="%1.1f%%")
plt.title("Gender Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# ## Age

# %%
df=pd.read_csv("retail_sales_dataset.csv")
plt.hist(df["Age"],bins=10)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # The average cutsutomer age is approximayely 41 years . The customer bas eranges from 18 o 64 years old , with the majority of customers falling bteween 29 and 55 year of age , This indicates that retail purchase are destributed across a wide range of adult age groups

# %% [markdown]
# ## Revenue by Product Category

# %%
category_revenue = df.groupby("Product Category")["Total Amount"].sum()

print(category_revenue)

category_revenue.plot(kind="bar", figsize=(8,5))

plt.title("Revenue by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Revenue")
plt.xticks(rotation=0)

plt.show()
# Out:
# Product Category
# Beauty         143515
# Clothing       155580
# Electronics    156905
# Name: Total Amount, dtype: int64

# %% [markdown]
# # Electronics generated the highest revenue (156,905), followed closely by Clothing (155,580). Beauty generated the lowest revenue (143,515). This indicates that Electronics is the most profitable product category and contributes the largest share to overall sales revenue.

# %% [markdown]
# Final Insights

# %%
print("Top Selling Category:")
print(df.groupby("Product Category")["Quantity"].sum().sort_values(ascending=False))

print("\nHighest Revenue Category:")
print(df.groupby("Product Category")["Total Amount"].sum().sort_values(ascending=False))

print("\nAverage Purchase by Gender:")
print(df.groupby("Gender")["Total Amount"].mean())
# Out:
# Top Selling Category:
# Product Category
# Clothing       894
# Electronics    849
# Beauty         771
# Name: Quantity, dtype: int64
#
# Highest Revenue Category:
# Product Category
# Electronics    156905
# Clothing       155580
# Beauty         143515
# Name: Total Amount, dtype: int64
#
# Average Purchase by Gender:
# Gender
# Female    456.549020
# Male      455.428571
# Name: Total Amount, dtype: float64

# %% [markdown]
# ## Key findings from the analysis include:
#
# -No missing or duplicate records.
# -Clothing is the most frequently purchased category.
# -Electronics generates the highest revenue.
# -Customer purchases are balanced across genders.
# -The average customer age is around 41 years
